# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing Files with help from Libraries

# %% [markdown]
# #### Januray 2021

# %%
df_Jan = pd.read_excel('Daily_Analysis_Dec_2021.xlsx', sheet_name= "Jan 2021", parse_dates= True)
df_Jan.head(10)
# Out:
#         Date   Analyst Name Reporting Shift Generated Alerts  Updated Alerts  \
# 0 2021-01-01  Jaya Warghade         Morning                4              11
# 1 2021-01-01  Ayaan Goswami       Afternoon               10              11
# 2 2021-01-01  Mirza Raichur           Night                1               5
# 3 2021-01-02  Jaya Warghade         Morning                8              10
# 4 2021-01-02   Hitesh Yetal       Afternoon               17              21
# 5 2021-01-02  Mirza Raichur           Night                2               9
# 6 2021-01-03  Jaya Warghade         Morning                5              10
# 7 2021-01-03   Hitesh Yetal       Afternoon               13              24
# 8 2021-01-03  Mirza Raichur           Night                1               9
# 9 2021-01-04  Jaya Warghade         Morning               10              12
#
#    Feed Read New Sources              Activities Performed Misc
# ...

# %%
df_Jan.shape
# Out:
# (106, 9)

# %%
df_Jan['Generated Alerts'].replace('-', 0, inplace= True)
df_Jan.head(5)
# Out:
#         Date   Analyst Name Reporting Shift  Generated Alerts  Updated Alerts  \
# 0 2021-01-01  Jaya Warghade         Morning                 4              11
# 1 2021-01-01  Ayaan Goswami       Afternoon                10              11
# 2 2021-01-01  Mirza Raichur           Night                 1               5
# 3 2021-01-02  Jaya Warghade         Morning                 8              10
# 4 2021-01-02   Hitesh Yetal       Afternoon                17              21
#
#    Feed Read New Sources              Activities Performed Misc
# 0       7456           -  Search updates for old incidents    -
# 1       7236           -  Search updates for old incidents    -
# 2       9432           -  Search updates for old incidents    -
# 3       8547           -  Search updates for old incidents    -
# 4       8999           -  Search updates for old incidents    -

# %%
df_Jan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  106 non-null    datetime64[ns]
#  1   Analyst Name          106 non-null    object
#  2   Reporting Shift       106 non-null    object
#  3   Generated Alerts      106 non-null    int64
#  4   Updated Alerts        106 non-null    int64
#  5   Feed Read             106 non-null    int64
#  6   New Sources           106 non-null    object
#  7   Activities Performed  106 non-null    object
#  8   Misc                  106 non-null    object
# dtypes: datetime64[ns](1), int64(3), object(5)
# memory usage: 7.6+ KB

# %%
df_Jan.describe()
# Out:
#        Generated Alerts  Updated Alerts    Feed Read
# count        106.000000      106.000000   106.000000
# mean           6.603774       10.716981  7655.066038
# std            4.578790        5.413835   971.230778
# min            0.000000        2.000000  4856.000000
# 25%            3.000000        7.000000  7153.500000
# 50%            6.000000       10.000000  7654.000000
# 75%           10.000000       13.750000  8329.250000
# max           18.000000       30.000000  9654.000000

# %%
jan_clear= df_Jan.drop(columns=['Feed Read', "New Sources", 'Activities Performed'])
jan_clear.head(6)
# Out:
#         Date   Analyst Name Reporting Shift  Generated Alerts  Updated Alerts  \
# 0 2021-01-01  Jaya Warghade         Morning                 4              11
# 1 2021-01-01  Ayaan Goswami       Afternoon                10              11
# 2 2021-01-01  Mirza Raichur           Night                 1               5
# 3 2021-01-02  Jaya Warghade         Morning                 8              10
# 4 2021-01-02   Hitesh Yetal       Afternoon                17              21
# 5 2021-01-02  Mirza Raichur           Night                 2               9
#
#   Misc
# 0    -
# 1    -
# 2    -
# 3    -
# 4    -
# 5    -

# %% [markdown]
# ##### Analysising who Generated and Updated more Alerts on January

# %%
j= jan_clear.groupby("Analyst Name")
j

# %%
j.get_group('Ayaan Goswami').head(4)
# Out:
#          Date   Analyst Name Reporting Shift  Generated Alerts  \
# 1  2021-01-01  Ayaan Goswami       Afternoon                10
# 11 2021-01-04  Ayaan Goswami           Night                 4
# 15 2021-01-05  Ayaan Goswami           Night                 2
# 19 2021-01-06  Ayaan Goswami           Night                 0
#
#     Updated Alerts Misc
# 1               11    -
# 11              14    -
# 15              10    -
# 19               9    -

# %%
plot_gen= j.plot.bar(x= 'Date', y= 'Generated Alerts')
plot_gen ### Here the bar graphs are going Alphabetically
# Out:
# Analyst Name
# Aashvi Shukla    AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami    AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal     AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade    AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
plot_updt= j.plot.bar(x= 'Date', y= 'Updated Alerts', color= 'red')

plot_updt ### Here the bar graphs are going Alphabetically
# Out:
# Analyst Name
# Aashvi Shukla    AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami    AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal     AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade    AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# ##### Who did the most night shift in January

# %%
jan_night= jan_clear['Reporting Shift']=='Night'
jan_shift= jan_clear[jan_night]
jan_shift
# Out:
#           Date   Analyst Name Reporting Shift  Generated Alerts  \
# 2   2021-01-01  Mirza Raichur           Night                 1
# 5   2021-01-02  Mirza Raichur           Night                 2
# 8   2021-01-03  Mirza Raichur           Night                 1
# 11  2021-01-04  Ayaan Goswami           Night                 4
# 15  2021-01-05  Ayaan Goswami           Night                 2
# 19  2021-01-06  Ayaan Goswami           Night                 0
# 22  2021-01-07  Ayaan Goswami           Night                 1
# 25  2021-01-08  Jaya Warghade           Night                 4
# 28  2021-01-09  Jaya Warghade           Night                 3
# 31  2021-01-10  Mirza Raichur           Night                 2
# 34  2021-01-11  Mirza Raichur           Night                 0
# 38  2021-01-12  Mirza Raichur           Night                 3
# 43  2021-01-13  Mirza Raichur           Night                 2
# 47  2021-01-14  Mirza Raichur           Night                 1
# ...

# %%
jan_count= jan_shift.value_counts('Analyst Name')
jan_count
# Out:
# Analyst Name
# Mirza Raichur    19
# Jaya Warghade     8
# Ayaan Goswami     4
# dtype: int64

# %%
jan_shift_group= jan_shift.groupby('Analyst Name')
jan_shift_group

# %%
jan_bar_gen= jan_shift_group.plot.box(x= 'Date', y= 'Generated Alerts', color='blue', title= 'Generated Alerts at Night')
jan_bar_gen
# Out:
# Analyst Name
# Ayaan Goswami    AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade    AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
jan_bar_upd= jan_shift_group.plot.box(x= 'Date', y= 'Updated Alerts', color='red', title= 'Updated Alerts at Night')
jan_bar_upd
# Out:
# Analyst Name
# Ayaan Goswami    AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade    AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# #### February 2021

# %%
df_Feb= pd.read_excel("Daily_Analysis_Dec_2021.xlsx", sheet_name= "Feb 2021", parse_dates= True)
df_Feb.head(10)
# Out:
#         Date   Analyst Name Reporting Shift Generated Alerts  Updated Alerts  \
# 0 2021-02-01  Ayaan Goswami         Morning               13              11
# 1 2021-02-01  Aashvi Shukla       Afternoon               12              10
# 2 2021-02-01  Mirza Raichur           Night                -               7
# 3 2021-02-02  Jaya Warghade         Morning                7               7
# 4 2021-02-02  Ayaan Goswami         Morning                5               9
# 5 2021-02-02  Aashvi Shukla       Afternoon                9              13
# 6 2021-02-02   Hitesh Yetal           Night                7              10
# 7 2021-02-03  Jaya Warghade         Morning                8              12
# 8 2021-02-03  Ayaan Goswami       Afternoon               11              15
# 9 2021-02-03   Hitesh Yetal           Night                5              13
#
#   Feed Read New Sources              Activities Performed         Misc
# ...

# %%
df_Feb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  96 non-null     datetime64[ns]
#  1   Analyst Name          96 non-null     object
#  2   Reporting Shift       96 non-null     object
#  3   Generated Alerts      96 non-null     object
#  4   Updated Alerts        96 non-null     int64
#  5   Feed Read             96 non-null     object
#  6   New Sources           96 non-null     object
#  7   Activities Performed  96 non-null     object
#  8   Misc                  96 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(7)
# memory usage: 6.9+ KB

# %%
df_Feb['Generated Alerts'].replace('-', 0, inplace= True)

# %%
feb_clear= df_Feb.drop(columns=['New Sources', "Activities Performed", 'Misc'])
feb_clear.head(4)
# Out:
#         Date   Analyst Name Reporting Shift  Generated Alerts  Updated Alerts  \
# 0 2021-02-01  Ayaan Goswami         Morning                13              11
# 1 2021-02-01  Aashvi Shukla       Afternoon                12              10
# 2 2021-02-01  Mirza Raichur           Night                 0               7
# 3 2021-02-02  Jaya Warghade         Morning                 7               7
#
#   Feed Read
# 0      7236
# 1      7654
# 2      9654
# 3      8256

# %% [markdown]
# ##### Analysising who Generated and Updated more Alerts on February

# %%
feb_clear.describe()
# Out:
#        Generated Alerts  Updated Alerts
# count         96.000000       96.000000
# mean           6.875000       11.239583
# std            4.178265        5.368024
# min            0.000000        1.000000
# 25%            4.000000        7.750000
# 50%            6.500000       10.000000
# 75%           10.000000       14.000000
# max           20.000000       28.000000

# %%
feb_group= feb_clear.groupby('Analyst Name')
feb_group

# %%
feb_group.get_group('Aashvi Shukla').head(4)
# Out:
#          Date   Analyst Name Reporting Shift  Generated Alerts  \
# 1  2021-02-01  Aashvi Shukla       Afternoon                12
# 5  2021-02-02  Aashvi Shukla       Afternoon                 9
# 14 2021-02-05  Aashvi Shukla         Morning                 7
# 17 2021-02-06  Aashvi Shukla         Morning                 5
#
#     Updated Alerts Feed Read
# 1               10      7654
# 5               13      7654
# 14               3      8965
# 17              10      6543

# %%
feb_bar_gen= feb_group.plot.bar(x='Date', y='Generated Alerts', color= "orange")
feb_bar_gen
# Out:
# Analyst Name
# Aashvi Shukla    AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami    AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal     AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade    AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
feb_bar_updt= feb_group.plot.bar(x='Date', y= 'Updated Alerts', color= 'pink')
feb_bar_updt
# Out:
# Analyst Name
# Aashvi Shukla    AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami    AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal     AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade    AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# ##### Who did the most night shift in February

# %%
feb_night= feb_clear['Reporting Shift']== 'Night'
feb_shift= feb_clear[feb_night]
feb_shift
# Out:
#          Date   Analyst Name Reporting Shift  Generated Alerts  \
# 2  2021-02-01  Mirza Raichur           Night                 0
# 6  2021-02-02   Hitesh Yetal           Night                 7
# 9  2021-02-03   Hitesh Yetal           Night                 5
# 12 2021-02-04   Hitesh Yetal           Night                 6
# 16 2021-02-05   Hitesh Yetal           Night                 6
# 20 2021-02-06   Hitesh Yetal           Night                 4
# 23 2021-02-07  Ayaan Goswami           Night                 7
# 26 2021-02-08  Ayaan Goswami           Night                 4
# 30 2021-02-09  Ayaan Goswami           Night                 4
# 33 2021-02-10  Ayaan Goswami           Night                 6
# 36 2021-02-11  Ayaan Goswami           Night                 3
# 54 2021-02-16  Ayaan Goswami           Night                 4
# 57 2021-02-17  Ayaan Goswami           Night                 5
# 60 2021-02-18  Ayaan Goswami           Night                 6
# ...

# %%
feb_shift_count= feb_shift.value_counts('Analyst Name')
feb_shift_count
# Out:
# Analyst Name
# Mirza Raichur    9
# Ayaan Goswami    8
# Hitesh Yetal     5
# Jaya Warghade    5
# dtype: int64

# %%
feb_shift_group= feb_shift.groupby('Analyst Name')
feb_shift_group

# %%
feb_bar_gen= feb_shift_group.plot.box(x= 'Date', y= 'Generated Alerts', color= 'Yellow', title='Generated Alerts at Night')
feb_bar_gen
# Out:
# Analyst Name
# Ayaan Goswami    AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal     AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade    AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
feb_bar_updt= feb_shift_group.plot.box(x= 'Date', y='Updated Alerts', color= 'pink', title='Updated Alerts at Night')
feb_bar_updt
# Out:
# Analyst Name
# Ayaan Goswami    AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal     AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade    AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# #### March 2021

# %%
df_March= pd.read_excel("Daily_Analysis_Dec_2021.xlsx", sheet_name= "March 2021", parse_dates= True)
df_March.head(10)
# Out:
#         Date   Analyst Name Reporting Shift Generated Alerts  Updated Alerts  \
# 0 2021-03-01  Ayaan Goswami         Morning               14               6
# 1 2021-03-01  Aashvi Shukla       Afternoon               12              14
# 2 2021-03-01  Mirza Raichur           Night                1              11
# 3 2021-03-02  Ayaan Goswami         Morning               11              10
# 4 2021-03-02  Aashvi Shukla       Afternoon                7               7
# 5 2021-03-02   Hitesh Yetal       Afternoon                5              21
# 6 2021-03-02  Jaya Warghade           Night                1              11
# 7 2021-03-03  Ayaan Goswami         Morning               10               9
# 8 2021-03-03   Hitesh Yetal       Afternoon               14              19
# 9 2021-03-03  Jaya Warghade           Night                2               8
#
#    Feed Read New Sources              Activities Performed         Misc
# ...

# %%
df_March.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  107 non-null    datetime64[ns]
#  1   Analyst Name          107 non-null    object
#  2   Reporting Shift       107 non-null    object
#  3   Generated Alerts      107 non-null    object
#  4   Updated Alerts        107 non-null    int64
#  5   Feed Read             107 non-null    int64
#  6   New Sources           107 non-null    object
#  7   Activities Performed  107 non-null    object
#  8   Misc                  107 non-null    object
# dtypes: datetime64[ns](1), int64(2), object(6)
# memory usage: 7.6+ KB

# %%
df_March['Generated Alerts'].replace('-', 0, inplace= True)

# %%
df_March.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  107 non-null    datetime64[ns]
#  1   Analyst Name          107 non-null    object
#  2   Reporting Shift       107 non-null    object
#  3   Generated Alerts      107 non-null    int64
#  4   Updated Alerts        107 non-null    int64
#  5   Feed Read             107 non-null    int64
#  6   New Sources           107 non-null    object
#  7   Activities Performed  107 non-null    object
#  8   Misc                  107 non-null    object
# dtypes: datetime64[ns](1), int64(3), object(5)
# memory usage: 7.6+ KB

# %%
march_clear= df_March.drop(columns=['New Sources', 'Activities Performed', 'Misc'])
march_clear.head(4)
# Out:
#         Date   Analyst Name Reporting Shift  Generated Alerts  Updated Alerts  \
# 0 2021-03-01  Ayaan Goswami         Morning                14               6
# 1 2021-03-01  Aashvi Shukla       Afternoon                12              14
# 2 2021-03-01  Mirza Raichur           Night                 1              11
# 3 2021-03-02  Ayaan Goswami         Morning                11              10
#
#    Feed Read
# 0       7236
# 1       7654
# 2       9332
# 3       7263

# %% [markdown]
# ##### Analysising who Generated and Updated more Alerts on March

# %%
march_group= march_clear.groupby('Analyst Name')
march_group

# %%
march_group.get_group('Mirza Raichur').tail(4)
# Out:
#          Date   Analyst Name Reporting Shift  Generated Alerts  \
# 84 2021-03-25  Mirza Raichur        Morning                  3
# 88 2021-03-26  Mirza Raichur         Morning                 4
# 94 2021-03-28  Mirza Raichur         Morning                 5
# 97 2021-03-29  Mirza Raichur         Morning                 7
#
#     Updated Alerts  Feed Read
# 84               4       6598
# 88               9       9754
# 94              11       7686
# 97               9       7545

# %%
march_gen= march_group.plot.bar(x= 'Date', y= 'Generated Alerts', color= 'grey')
march_gen
# Out:
# Analyst Name
# Aashvi Shukla    AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami    AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal     AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade    AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
march_updt= march_group.plot.bar(x= 'Date', y= 'Updated Alerts', color= 'silver')
march_updt
# Out:
# Analyst Name
# Aashvi Shukla    AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami    AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal     AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade    AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# ##### Who did the most night shift in March

# %%
March_night= march_clear['Reporting Shift']=='Night'
march_night_shift= march_clear[March_night]
march_night_shift.head(5)
# Out:
#          Date   Analyst Name Reporting Shift  Generated Alerts  \
# 2  2021-03-01  Mirza Raichur           Night                 1
# 6  2021-03-02  Jaya Warghade           Night                 1
# 9  2021-03-03  Jaya Warghade           Night                 2
# 12 2021-03-04  Jaya Warghade           Night                 1
# 15 2021-03-05  Jaya Warghade           Night                 2
#
#     Updated Alerts  Feed Read
# 2               11       9332
# 6               11       6896
# 9                8       7926
# 12              17       7896
# 15               7       6523

# %%
march_shift_count= march_night_shift.value_counts('Analyst Name')
march_shift_count
# Out:
# Analyst Name
# Jaya Warghade    10
# Ayaan Goswami     9
# Mirza Raichur     6
# Aashvi Shukla     5
# Hitesh Yetal      5
# dtype: int64

# %%
march_shift_group= march_night_shift.groupby('Analyst Name')
march_shift_group

# %%
march_bar_gen= march_shift_group.plot.box(x= 'Date', y= 'Generated Alerts', color='Grey', title= 'Generated Alerts at Night')
march_bar_gen
# Out:
# Analyst Name
# Aashvi Shukla    AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami    AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal     AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade    AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
march_bar_updt= march_shift_group.plot.box(x= 'Date', y='Updated Alerts', color= 'silver', title= 'Updated Alerts at Night')
march_bar_updt
# Out:
# Analyst Name
# Aashvi Shukla    AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami    AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal     AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade    AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# #### April 2021

# %%
df_April= pd.read_excel('Daily_Analysis_Dec_2021.xlsx', sheet_name= 'April 2021', parse_dates= True)
df_April.head(10)
# Out:
#         Date    Analyst Name Reporting Shift Generated Alerts  Updated Alerts  \
# 0 2021-04-01   Jaya Warghade        Morning                11               8
# 1 2021-04-01    Hitesh Yetal       Afternoon               14              16
# 2 2021-04-01  Ayaan Goswami           Night                 2              14
# 3 2021-04-02   Jaya Warghade        Morning                 8              16
# 4 2021-04-02   Aashvi Shukla       Afternoon                4               5
# 5 2021-04-02    Hitesh Yetal       Afternoon                4              12
# 6 2021-04-02   Mirza Raichur          Night                 1               9
# 7 2021-04-03   Jaya Warghade        Morning                16              13
# 8 2021-04-03    Hitesh Yetal       Afternoon                7               7
# 9 2021-04-03   Aashvi Shukla       Afternoon                3              13
#
#    Feed Read New Sources              Activities Performed Misc
# ...

# %%
df_April['Generated Alerts'].replace('-', 0, inplace= True)

# %%
df_April.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  100 non-null    datetime64[ns]
#  1   Analyst Name          100 non-null    object
#  2   Reporting Shift       100 non-null    object
#  3   Generated Alerts      100 non-null    int64
#  4   Updated Alerts        100 non-null    int64
#  5   Feed Read             100 non-null    int64
#  6   New Sources           99 non-null     object
#  7   Activities Performed  100 non-null    object
#  8   Misc                  99 non-null     object
# dtypes: datetime64[ns](1), int64(3), object(5)
# memory usage: 7.2+ KB

# %%
clear_april= df_April.drop(columns=['New Sources', 'Activities Performed', 'Misc'])
clear_april.head(4)
# Out:
#         Date    Analyst Name Reporting Shift  Generated Alerts  \
# 0 2021-04-01   Jaya Warghade        Morning                 11
# 1 2021-04-01    Hitesh Yetal       Afternoon                14
# 2 2021-04-01  Ayaan Goswami           Night                  2
# 3 2021-04-02   Jaya Warghade        Morning                  8
#
#    Updated Alerts  Feed Read
# 0               8       6896
# 1              16       8567
# 2              14       6598
# 3              16       7965

# %% [markdown]
# ##### Analysising who Generated and Updated more Alerts on April

# %%
april_group= clear_april.groupby('Analyst Name')
april_group

# %%
april_group.get_group("Jaya Warghade").head()
# Out:
#          Date   Analyst Name Reporting Shift  Generated Alerts  \
# 0  2021-04-01  Jaya Warghade        Morning                 11
# 3  2021-04-02  Jaya Warghade        Morning                  8
# 7  2021-04-03  Jaya Warghade        Morning                 16
# 18 2021-04-06  Jaya Warghade       Afternoon                 2
# 23 2021-04-07  Jaya Warghade       Afternoon                 8
#
#     Updated Alerts  Feed Read
# 0                8       6896
# 3               16       7965
# 7               13       8965
# 18              12       5454
# 23              22       8965

# %%
april_gen= april_group.plot.bar(x= 'Date', y= 'Generated Alerts')
april_gen
# Out:
# Analyst Name
# Aashvi Shukla     AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami     AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal      AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade     AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
april_updt= april_group.plot.bar(x= 'Date', y= 'Updated Alerts', color= 'red')
april_updt
# Out:
# Analyst Name
# Aashvi Shukla     AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami     AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal      AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade     AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# ##### Who did the most night shift in April

# %%
April_night= clear_april['Reporting Shift']=='Night '
april_night_shift= clear_april[April_night]
april_night_shift.tail(5)
# Out:
#          Date   Analyst Name Reporting Shift  Generated Alerts  \
# 88 2021-04-26  Mirza Raichur          Night                  1
# 92 2021-04-27  Mirza Raichur          Night                  1
# 93 2021-04-27   Hitesh Yetal          Night                  1
# 96 2021-04-28   Hitesh Yetal          Night                  4
# 99 2021-04-29   Hitesh Yetal          Night                  5
#
#     Updated Alerts  Feed Read
# 88               4       8654
# 92               4       5489
# 93               3       5123
# 96              14       7863
# 99              11       7456

# %%
april_night_shift.value_counts("Analyst Name")
# Out:
# Analyst Name
# Mirza Raichur     10
# Hitesh Yetal       8
# Ayaan Goswami      6
# Jaya Warghade      5
# Aashvi Shukla      4
# dtype: int64

# %%
april_night_group= april_night_shift.groupby("Analyst Name")
april_night_group

# %%
april_bar_gen= april_night_group.plot.box(x= 'Date', y= 'Generated Alerts', color='red', title= 'Generated Alerts at Night')
april_bar_gen
# Out:
# Analyst Name
# Aashvi Shukla     AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami     AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal      AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade     AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
april_bar_updt= april_night_group.plot.box(x= 'Date', y= 'Updated Alerts', color='green', title= 'Updated Alerts at Night')
april_bar_updt
# Out:
# Analyst Name
# Aashvi Shukla     AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami     AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal      AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade     AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# #### May 2021

# %%
df_May= pd.read_excel('Daily_Analysis_Dec_2021.xlsx', sheet_name= "May 2021", parse_dates= True)
df_May.head(10)
# Out:
#         Date   Analyst Name Reporting Shift Generated Alerts  Updated Alerts  \
# 0 2021-05-01  Aashvi Shukla        Morning                 5               9
# 1 2021-05-01  Jaya Warghade      Afternoon                 4              16
# 2 2021-05-01   Hitesh Yetal           Night                3               9
# 3 2021-05-02  Aashvi Shukla        Morning                 5               9
# 4 2021-05-02  Ayaan Goswami      Afternoon                 8              13
# 5 2021-05-02  Mirza Raichur           Night                -               6
# 6 2021-05-03  Aashvi Shukla        Morning                 5              11
# 7 2021-05-03  Ayaan Goswami      Afternoon                11              13
# 8 2021-05-03  Mirza Raichur           Night                -               3
# 9 2021-05-03  Jaya Warghade           Night                2              10
#
#    Feed Read New Sources              Activities Performed Misc
# ...

# %%
df_May['Generated Alerts'].replace('-', 0, inplace= True)

# %%
df_May.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  107 non-null    datetime64[ns]
#  1   Analyst Name          107 non-null    object
#  2   Reporting Shift       107 non-null    object
#  3   Generated Alerts      107 non-null    int64
#  4   Updated Alerts        107 non-null    int64
#  5   Feed Read             107 non-null    int64
#  6   New Sources           105 non-null    object
#  7   Activities Performed  107 non-null    object
#  8   Misc                  107 non-null    object
# dtypes: datetime64[ns](1), int64(3), object(5)
# memory usage: 7.6+ KB

# %%
may_clear= df_May.drop(columns=['New Sources', 'Activities Performed', 'Misc'])
may_clear.head()
# Out:
#         Date   Analyst Name Reporting Shift  Generated Alerts  Updated Alerts  \
# 0 2021-05-01  Aashvi Shukla        Morning                  5               9
# 1 2021-05-01  Jaya Warghade      Afternoon                  4              16
# 2 2021-05-01   Hitesh Yetal           Night                 3               9
# 3 2021-05-02  Aashvi Shukla        Morning                  5               9
# 4 2021-05-02  Ayaan Goswami      Afternoon                  8              13
#
#    Feed Read
# 0       7654
# 1       7896
# 2       7459
# 3       7654
# 4       7458

# %% [markdown]
# ##### Analysising who Generated and Updated more Alerts on May

# %%
may_group= may_clear.groupby('Analyst Name')
may_group

# %%
may_group.get_group('Hitesh Yetal').head(5)
# Out:
#          Date  Analyst Name Reporting Shift  Generated Alerts  Updated Alerts  \
# 2  2021-05-01  Hitesh Yetal           Night                 3               9
# 11 2021-05-04  Hitesh Yetal        Morning                  4               3
# 15 2021-05-05  Hitesh Yetal        Morning                  8               8
# 18 2021-05-06  Hitesh Yetal        Morning                  8               9
# 21 2021-05-06  Hitesh Yetal        Morning                 15              13
#
#     Feed Read
# 2        7459
# 11       5487
# 15       8523
# 18       8152
# 21       8643

# %%
may_gen= may_group.plot.bar(x= 'Date', y= 'Generated Alerts', color= 'green')
may_gen
# Out:
# Analyst Name
# Aashvi Shukla    AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami    AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal     AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade    AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
may_updt= may_group.plot.bar(x= 'Date', y='Updated Alerts', color='pink')
may_updt
# Out:
# Analyst Name
# Aashvi Shukla    AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami    AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal     AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade    AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# ##### Who did the most night shift in May

# %%
may_night= may_clear["Reporting Shift"]== 'Night'
may_night_shift= may_clear[may_night]
may_night_shift.tail(3)
# Out:
#           Date   Analyst Name Reporting Shift  Generated Alerts  \
# 102 2021-05-30  Ayaan Goswami           Night                 3
# 105 2021-05-31  Mirza Raichur           Night                 0
# 106 2021-05-31  Ayaan Goswami           Night                 2
#
#      Updated Alerts  Feed Read
# 102               5       8643
# 105               4       9432
# 106              10       8643

# %%
may_night_shift.value_counts('Analyst Name')
# Out:
# Analyst Name
# Mirza Raichur    12
# Jaya Warghade     9
# Ayaan Goswami     7
# Hitesh Yetal      6
# Aashvi Shukla     5
# dtype: int64

# %%
may_night_group= may_night_shift.groupby('Analyst Name')
may_night_group

# %%
may_night_gen= may_night_group.plot.box(x= 'Date', y= 'Generated Alerts', color='purple', title= 'Generated Alerts at Night')
may_night_gen
# Out:
# Analyst Name
# Aashvi Shukla    AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami    AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal     AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade    AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
may_night_updt= may_night_group.plot.box(x= 'Date', y='Updated Alerts', color='orange', title= 'Updated Alerts at Night')
may_night_updt
# Out:
# Analyst Name
# Aashvi Shukla    AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami    AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal     AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade    AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# #### June 2021

# %%
df_June=pd.read_excel('Daily_Analysis_Dec_2021.xlsx', sheet_name= 'June 2021', parse_dates= True)
df_June.head(10)
# Out:
#         Date    Analyst Name Reporting Shift Generated Alerts  Updated Alerts  \
# 0 2021-06-01   Jaya Warghade        Morning                 6              15
# 1 2021-06-01    Hitesh Yetal       Afternoon                6              18
# 2 2021-06-01  Mirza Raichur            Night                -               5
# 3 2021-06-01  Ayaan Goswami            Night                2               4
# 4 2021-06-02   Jaya Warghade        Morning                 4               9
# 5 2021-06-02    Hitesh Yetal       Afternoon                9              16
# 6 2021-06-02  Ayaan Goswami            Night                3               8
# 7 2021-06-03   Jaya Warghade        Morning                 9               9
# 8 2021-06-03    Hitesh Yetal       Afternoon                4              13
# 9 2021-06-03   Aashvi Shukla           Night                -               6
#
#    Feed Read New Sources              Activities Performed  \
# ...

# %%
df_June['Generated Alerts']. replace('-', 0, inplace= True)

# %%
df_June.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  103 non-null    datetime64[ns]
#  1   Analyst Name          103 non-null    object
#  2   Reporting Shift       103 non-null    object
#  3   Generated Alerts      103 non-null    int64
#  4   Updated Alerts        103 non-null    int64
#  5   Feed Read             103 non-null    int64
#  6   New Sources           103 non-null    object
#  7   Activities Performed  103 non-null    object
#  8   Misc                  103 non-null    object
# dtypes: datetime64[ns](1), int64(3), object(5)
# memory usage: 7.4+ KB

# %%
clear_june= df_June.drop(columns= ['New Sources', "Activities Performed", 'Misc'])
clear_june.head(5)
# Out:
#         Date    Analyst Name Reporting Shift  Generated Alerts  \
# 0 2021-06-01   Jaya Warghade        Morning                  6
# 1 2021-06-01    Hitesh Yetal       Afternoon                 6
# 2 2021-06-01  Mirza Raichur            Night                 0
# 3 2021-06-01  Ayaan Goswami            Night                 2
# 4 2021-06-02   Jaya Warghade        Morning                  4
#
#    Updated Alerts  Feed Read
# 0              15       7154
# 1              18       7854
# 2               5       9554
# 3               4       9533
# 4               9       7921

# %% [markdown]
# ##### Analysising who Generated and Updated more Alerts on June.

# %%
june_group= clear_june.groupby('Analyst Name')
june_group

# %%
june_group.get_group('Ayaan Goswami ').head(3)
# Out:
#          Date    Analyst Name Reporting Shift  Generated Alerts  \
# 3  2021-06-01  Ayaan Goswami            Night                 2
# 6  2021-06-02  Ayaan Goswami            Night                 3
# 10 2021-06-03  Ayaan Goswami            Night                 3
#
#     Updated Alerts  Feed Read
# 3                4       9533
# 6                8       7201
# 10               4       5455

# %%
june_gen= june_group.plot.bar(x='Date', y='Generated Alerts', color= 'grey')
june_gen
# Out:
# Analyst Name
# Aashvi Shukla     AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami     AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal      AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade     AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
june_updt= june_group.plot.bar(x= 'Date', y= 'Updated Alerts', color= 'silver')
june_updt
# Out:
# Analyst Name
# Aashvi Shukla     AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami     AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal      AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade     AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# ##### Who did the most night shift in June

# %%
June_night= clear_june['Reporting Shift']== 'Night'
june_shift_night=clear_june[June_night]
june_shift_night.tail(3)
# Out:
#           Date   Analyst Name Reporting Shift  Generated Alerts  \
# 96  2021-06-28  Aashvi Shukla           Night                 1
# 99  2021-06-29   Hitesh Yetal           Night                 4
# 102 2021-06-30   Hitesh Yetal           Night                 4
#
#      Updated Alerts  Feed Read
# 96                7       7655
# 99                6       7354
# 102               8       7258

# %%
june_shift_night.value_counts('Analyst Name')
# Out:
# Analyst Name
# Aashvi Shukla     10
# Ayaan Goswami      7
# Hitesh Yetal       7
# Mirza Raichur      6
# Jaya Warghade      5
# dtype: int64

# %%
june_night_group= june_shift_night.groupby('Analyst Name')
june_night_group

# %%
june_bar_gen= june_night_group.plot.box(x= 'Date', y= 'Generated Alerts', color= 'blue', title= 'Generated Alerts at Night')
june_bar_gen
# Out:
# Analyst Name
# Aashvi Shukla     AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami     AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal      AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade     AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
june_bar_upd= june_night_group.plot.box(x='Date', y='Updated Alerts', color='red', title='Updated Alerts at Night')
june_bar_upd
# Out:
# Analyst Name
# Aashvi Shukla     AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami     AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal      AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade     AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# #### July 2021

# %%
df_July= pd.read_excel('Daily_Analysis_Dec_2021.xlsx', sheet_name= 'July 2021', parse_dates= True)
df_July.head(10)
# Out:
#         Date    Analyst Name Reporting Shift  Generated Alerts  \
# 0 2021-07-01   Ayaan Goswami        Morning                  8
# 1 2021-07-01   Jaya Warghade       Afternoon                 6
# 2 2021-07-01  Aashvi Shukla            Night                 3
# 3 2021-07-02  Mirza Raichur         Morning                  4
# 4 2021-07-02  Aashvi Shukla        Afternoon                 8
# 5 2021-07-02    Hitesh Yetal           Night                 8
# 6 2021-07-03  Mirza Raichur         Morning                  4
# 7 2021-07-03    Hitesh Yetal       Afternoon                14
# 8 2021-07-03  Aashvi Shukla            Night                 5
# 9 2021-07-04  Mirza Raichur         Morning                  4
#
#    Updated Alerts  Feed Read New Sources              Activities Performed  \
# 0               9       7154           -  Search updates for old incidents
# 1              12       7854           -  Search updates for old incidents
# ...

# %%
df_July.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  103 non-null    datetime64[ns]
#  1   Analyst Name          103 non-null    object
#  2   Reporting Shift       103 non-null    object
#  3   Generated Alerts      103 non-null    int64
#  4   Updated Alerts        103 non-null    int64
#  5   Feed Read             103 non-null    int64
#  6   New Sources           103 non-null    object
#  7   Activities Performed  103 non-null    object
#  8   Misc                  97 non-null     object
# dtypes: datetime64[ns](1), int64(3), object(5)
# memory usage: 7.4+ KB

# %%
clean_july= df_July.drop(columns=['New Sources', 'Activities Performed', 'Misc'])
clean_july.head(4)
# Out:
#         Date    Analyst Name Reporting Shift  Generated Alerts  \
# 0 2021-07-01   Ayaan Goswami        Morning                  8
# 1 2021-07-01   Jaya Warghade       Afternoon                 6
# 2 2021-07-01  Aashvi Shukla            Night                 3
# 3 2021-07-02  Mirza Raichur         Morning                  4
#
#    Updated Alerts  Feed Read
# 0               9       7154
# 1              12       7854
# 2               7       7654
# 3               7       7655

# %% [markdown]
# ##### Analysising who Generated and Updated more Alerts on July

# %%
july_group= clean_july.groupby('Analyst Name')
july_group

# %%
july_group.get_group('Jaya Warghade').head(4)
# Out:
#          Date   Analyst Name Reporting Shift  Generated Alerts  \
# 1  2021-07-01  Jaya Warghade       Afternoon                 6
# 10 2021-07-04  Jaya Warghade       Afternoon                 6
# 14 2021-07-05  Jaya Warghade       Afternoon                 5
# 17 2021-07-06  Jaya Warghade       Afternoon                 5
#
#     Updated Alerts  Feed Read
# 1               12       7854
# 10              27       7836
# 14              15       7958
# 17              18       8496

# %%
july_gen = july_group.plot.bar(x= 'Date', y= 'Generated Alerts')

# %%
july_updt= july_group.plot.bar(x= 'Date', y= 'Updated Alerts', color= 'red')
july_updt
# Out:
# Analyst Name
# Aashvi Shukla     AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami     AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal      AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade     AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# ##### Who did the most night shift in July

# %%
July_night= clean_july['Reporting Shift']== 'Night'
july_night_shift= clean_july[July_night]
july_night_shift.head(4)
# Out:
#          Date    Analyst Name Reporting Shift  Generated Alerts  \
# 2  2021-07-01  Aashvi Shukla            Night                 3
# 5  2021-07-02    Hitesh Yetal           Night                 8
# 8  2021-07-03  Aashvi Shukla            Night                 5
# 11 2021-07-04  Aashvi Shukla            Night                 1
#
#     Updated Alerts  Feed Read
# 2                7       7654
# 5                8       7290
# 8               11       7654
# 11               4       6598

# %%
july_night_shift.value_counts('Analyst Name')
# Out:
# Analyst Name
# Aashvi Shukla     12
# Ayaan Goswami     11
# Jaya Warghade      5
# Mirza Raichur      4
# Hitesh Yetal       3
# dtype: int64

# %%
july_shift_group= july_night_shift.groupby('Analyst Name')
july_shift_group

# %%
july_bar_gen= july_shift_group.plot.box(x= 'Date', y= 'Generated Alerts', color= 'pink', title='Generated Alerts at Night')
july_bar_gen
# Out:
# Analyst Name
# Aashvi Shukla     AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami     AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal      AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade     AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
july_bar_updt= july_shift_group.plot.box(x= 'Date', y='Updated Alerts', color= 'orange', title= 'Updated Alerts at Night')
july_bar_updt
# Out:
# Analyst Name
# Aashvi Shukla     AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami     AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal      AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade     AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# #### August 2021

# %%
df_Aug= pd.read_excel('Daily_Analysis_Dec_2021.xlsx', sheet_name= 'August 2021', parse_dates= True)
df_Aug.head(10)
# Out:
#         Date   Analyst Name Reporting Shift Generated Alerts  Updated Alerts  \
# 0 2021-08-01  Ayaan Goswami        Morning                 9              12
# 1 2021-08-01  Mirza Raichur       Afternoon                5               9
# 2 2021-08-01  Aashvi Shukla           Night                4               5
# 3 2021-08-02  Ayaan Goswami        Morning                 9              11
# 4 2021-08-02  Mirza Raichur       Afternoon                7              12
# 5 2021-08-02  Aashvi Shukla           Night                3               5
# 6 2021-08-03  Ayaan Goswami        Morning                 8              11
# 7 2021-08-03   Hitesh Yetal           Night                3               5
# 8 2021-08-04  Ayaan Goswami        Morning                 9              13
# 9 2021-08-04  Aashvi Shukla       Afternoon               15              13
#
#    Feed Read New Sources              Activities Performed Misc
# ...

# %%
df_Aug['Generated Alerts'].replace('-',0, inplace= True)

# %%
df_Aug.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  99 non-null     datetime64[ns]
#  1   Analyst Name          99 non-null     object
#  2   Reporting Shift       99 non-null     object
#  3   Generated Alerts      99 non-null     int64
#  4   Updated Alerts        99 non-null     int64
#  5   Feed Read             99 non-null     int64
#  6   New Sources           99 non-null     object
#  7   Activities Performed  99 non-null     object
#  8   Misc                  99 non-null     object
# dtypes: datetime64[ns](1), int64(3), object(5)
# memory usage: 7.1+ KB

# %%
clear_aug= df_Aug.drop(columns=['New Sources', 'Activities Performed', 'Misc'])
clear_aug.head(3)
# Out:
#         Date   Analyst Name Reporting Shift  Generated Alerts  Updated Alerts  \
# 0 2021-08-01  Ayaan Goswami        Morning                  9              12
# 1 2021-08-01  Mirza Raichur       Afternoon                 5               9
# 2 2021-08-01  Aashvi Shukla           Night                 4               5
#
#    Feed Read
# 0       7154
# 1       8646
# 2       7645

# %% [markdown]
# ##### Analysising who Generated and Updated more Alerts on August

# %%
aug_group= clear_aug.groupby('Analyst Name')
aug_group

# %%
aug_group.get_group('Mirza Raichur').head(3)
# Out:
#          Date   Analyst Name Reporting Shift  Generated Alerts  \
# 1  2021-08-01  Mirza Raichur       Afternoon                 5
# 4  2021-08-02  Mirza Raichur       Afternoon                 7
# 19 2021-08-07  Mirza Raichur           Night                 1
#
#     Updated Alerts  Feed Read
# 1                9       8646
# 4               12       9443
# 19              13       8764

# %%
aug_gen= aug_group.plot.bar(x= 'Date', y= 'Generated Alerts', color= 'green')
aug_gen
# Out:
# Analyst Name
# Aashvi Shukla    AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami    AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal     AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade    AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
aug_updt= aug_group.plot.bar(x= 'Date', y='Updated Alerts', color='pink')
aug_updt
# Out:
# Analyst Name
# Aashvi Shukla    AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami    AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal     AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade    AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# ##### Who did the most night shift in August

# %%
Aug_night= clear_aug['Reporting Shift']== 'Night'
aug_night_shift= clear_aug[Aug_night]
aug_night_shift.tail(4)
# Out:
#          Date   Analyst Name Reporting Shift  Generated Alerts  \
# 89 2021-08-28  Mirza Raichur           Night                 0
# 92 2021-08-29  Mirza Raichur           Night                 1
# 95 2021-08-30  Mirza Raichur           Night                 0
# 98 2021-08-31  Mirza Raichur           Night                 1
#
#     Updated Alerts  Feed Read
# 89               9       9864
# 92               7       7654
# 95               9       7643
# 98              11       8765

# %%
aug_night_shift.value_counts('Analyst Name')
# Out:
# Analyst Name
# Mirza Raichur    8
# Aashvi Shukla    7
# Ayaan Goswami    5
# Hitesh Yetal     5
# Jaya Warghade    5
# dtype: int64

# %%
aug_night_group= aug_night_shift.groupby('Analyst Name')
aug_night_group

# %%
aug_bar_gen= aug_night_group.plot.box(x='Date', y='Generated Alerts', color='purple', title='Generated Alerts at Night')
aug_bar_gen
# Out:
# Analyst Name
# Aashvi Shukla    AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami    AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal     AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade    AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
aug_bar_updt= aug_night_group.plot.box(x='Date', y='Updated Alerts', color='grey', title='Updated Alerts at Night')
aug_bar_updt
# Out:
# Analyst Name
# Aashvi Shukla    AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami    AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal     AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade    AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# #### September 2021

# %%
df_Sep= pd.read_excel('Daily_Analysis_Dec_2021.xlsx', sheet_name= 'September 2021', parse_dates= True)
df_Sep.head(10)
# Out:
#         Date   Analyst Name Reporting Shift Generated Alerts  Updated Alerts  \
# 0 2021-09-01  Ayaan Goswami        Morning                 8              14
# 1 2021-09-01   Hitesh Yetal       Afternoon               14              15
# 2 2021-09-01  Jaya Warghade          Night                 -              18
# 3 2021-09-02  Ayaan Goswami        Morning                11              13
# 4 2021-09-02   Hitesh Yetal       Afternoon               11              18
# 5 2021-09-02  Jaya Warghade          Night                 -               5
# 6 2021-09-02  Aashvi Shukla          Night                 -               9
# 7 2021-09-03  Mirza Raichur        Morning                 5               9
# 8 2021-09-03   Hitesh Yetal       Afternoon               10              16
# 9 2021-09-03  Aashvi Shukla          Night                 -               7
#
#    Feed Read New Sources              Activities Performed Misc
# ...

# %%
df_Sep['Generated Alerts'].replace('-',0,inplace=True)

# %%
df_Sep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  103 non-null    datetime64[ns]
#  1   Analyst Name          103 non-null    object
#  2   Reporting Shift       103 non-null    object
#  3   Generated Alerts      103 non-null    int64
#  4   Updated Alerts        103 non-null    int64
#  5   Feed Read             103 non-null    int64
#  6   New Sources           103 non-null    object
#  7   Activities Performed  103 non-null    object
#  8   Misc                  103 non-null    object
# dtypes: datetime64[ns](1), int64(3), object(5)
# memory usage: 7.4+ KB

# %%
clear_sep= df_Sep.drop(columns=['New Sources', 'Activities Performed', 'Misc'])
clear_sep.head(4)
# Out:
#         Date   Analyst Name Reporting Shift  Generated Alerts  Updated Alerts  \
# 0 2021-09-01  Ayaan Goswami        Morning                  8              14
# 1 2021-09-01   Hitesh Yetal       Afternoon                14              15
# 2 2021-09-01  Jaya Warghade          Night                  0              18
# 3 2021-09-02  Ayaan Goswami        Morning                 11              13
#
#    Feed Read
# 0       7154
# 1       8743
# 2       8729
# 3       7569

# %% [markdown]
# ##### Analysising who Generated and Updated more Alerts on September

# %%
sep_group= clear_sep.groupby('Analyst Name')
sep_group

# %%
sep_gen= sep_group.plot.bar(x='Date', y='Generated Alerts', color='grey')
sep_gen
# Out:
# Analyst Name
# Aashvi Shukla    AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami    AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal     AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade    AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
sep_updt= sep_group.plot.bar(x= 'Date', y= 'Updated Alerts', color='silver')
sep_updt
# Out:
# Analyst Name
# Aashvi Shukla    AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami    AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal     AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade    AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# ##### Who did the most night shift in September

# %%
Sep_night= clear_sep['Reporting Shift']== 'Night '
sep_night_shift= clear_sep[Sep_night]
sep_night_shift.head()
# Out:
#          Date   Analyst Name Reporting Shift  Generated Alerts  \
# 2  2021-09-01  Jaya Warghade          Night                  0
# 5  2021-09-02  Jaya Warghade          Night                  0
# 6  2021-09-02  Aashvi Shukla          Night                  0
# 9  2021-09-03  Aashvi Shukla          Night                  0
# 12 2021-09-04  Aashvi Shukla          Night                  1
#
#     Updated Alerts  Feed Read
# 2               18       8729
# 5                5       6741
# 6                9       6754
# 9                7       7654
# 12              13       7654

# %%
sep_night_shift.value_counts('Analyst Name')
# Out:
# Analyst Name
# Aashvi Shukla    9
# Hitesh Yetal     8
# Jaya Warghade    7
# Ayaan Goswami    6
# Mirza Raichur    5
# dtype: int64

# %%
sep_night_group= sep_night_shift.groupby('Analyst Name')
sep_night_group

# %%
sep_bar_gen= sep_night_group.plot.box(x= 'Date', y= 'Generated Alerts', color= 'grey', title= 'Generated Alerts at Night')
sep_bar_gen
# Out:
# Analyst Name
# Aashvi Shukla    AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami    AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal     AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade    AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
sep_bar_updt= sep_night_group.plot.box(x= 'Date', y= 'Updated Alerts', color= 'orange', title= 'Updated Alerts at Night')
sep_bar_updt
# Out:
# Analyst Name
# Aashvi Shukla    AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami    AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal     AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade    AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# #### October 2021

# %%
df_Oct= pd.read_excel('Daily_Analysis_Dec_2021.xlsx', sheet_name= 'October 2021', parse_dates= True)
df_Oct.head(10)
# Out:
#         Date    Analyst Name Reporting Shift Generated Alerts  Updated Alerts  \
# 0 2021-10-01   Ayaan Goswami        Morning                 8              14
# 1 2021-10-01   Mirza Raichur       Afternoon                9              17
# 2 2021-10-01    Hitesh Yetal           Night                7              10
# 3 2021-10-02   Ayaan Goswami        Morning                12              16
# 4 2021-10-02   Mirza Raichur       Afternoon                5              22
# 5 2021-10-02    Hitesh Yetal           Night                5              11
# 6 2021-10-03   Aashvi Shukla        Morning                 8               8
# 7 2021-10-03   Mirza Raichur       Afternoon                5              15
# 8 2021-10-03  Jaya Warghade            Night                4              13
# 9 2021-10-04   Aashvi Shukla        Morning                 8              10
#
#    Feed Read New Sources              Activities Performed  \
# ...

# %%
df_Oct['Generated Alerts'].replace('-',0,inplace=True)

# %%
df_Oct.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  106 non-null    datetime64[ns]
#  1   Analyst Name          106 non-null    object
#  2   Reporting Shift       106 non-null    object
#  3   Generated Alerts      106 non-null    int64
#  4   Updated Alerts        106 non-null    int64
#  5   Feed Read             106 non-null    int64
#  6   New Sources           106 non-null    object
#  7   Activities Performed  106 non-null    object
#  8   Misc                  106 non-null    object
# dtypes: datetime64[ns](1), int64(3), object(5)
# memory usage: 7.6+ KB

# %%
clear_oct= df_Oct.drop(columns=['New Sources', 'Activities Performed', 'Misc'])
clear_oct.head(3)
# Out:
#         Date   Analyst Name Reporting Shift  Generated Alerts  Updated Alerts  \
# 0 2021-10-01  Ayaan Goswami        Morning                  8              14
# 1 2021-10-01  Mirza Raichur       Afternoon                 9              17
# 2 2021-10-01   Hitesh Yetal           Night                 7              10
#
#    Feed Read
# 0       7154
# 1       8543
# 2       7654

# %% [markdown]
# ##### Analysising who Generated and Updated more Alerts on October

# %%
oct_group= clear_oct.groupby('Analyst Name')
oct_group

# %%
oct_gen=oct_group.plot.bar(x= 'Date', y= 'Generated Alerts')
oct_gen
# Out:
# Analyst Name
# Aashvi Shukla     AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami     AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal      AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade     AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
oct_updt= oct_group.plot.bar(x='Date', y='Updated Alerts', color='red')
oct_updt
# Out:
# Analyst Name
# Aashvi Shukla     AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami     AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal      AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade     AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# ##### Who did the most night shift in October

# %%
Oct_night= clear_oct['Reporting Shift']== 'Night'
oct_night_shift= clear_oct[Oct_night]
oct_night_shift.head()
# Out:
#          Date    Analyst Name Reporting Shift  Generated Alerts  \
# 2  2021-10-01    Hitesh Yetal           Night                 7
# 5  2021-10-02    Hitesh Yetal           Night                 5
# 8  2021-10-03  Jaya Warghade            Night                 4
# 11 2021-10-04  Jaya Warghade            Night                 1
# 16 2021-10-05  Jaya Warghade            Night                 1
#
#     Updated Alerts  Feed Read
# 2               10       7654
# 5               11       8642
# 8               13       7193
# 11              10       8765
# 16              14       7915

# %%
oct_night_shift.value_counts('Analyst Name')
# Out:
# Analyst Name
# Jaya Warghade     11
# Mirza Raichur      8
# Hitesh Yetal       7
# Aashvi Shukla      5
# Ayaan Goswami      2
# dtype: int64

# %%
oct_night_group= oct_night_shift.groupby('Analyst Name')
oct_night_group

# %%
oct_bar_gen= oct_night_group.plot.box(x= 'Date', y= 'Generated Alerts', color= 'blue', title= 'Generated Alerts at Night')
oct_bar_gen
# Out:
# Analyst Name
# Aashvi Shukla     AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami     AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal      AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade     AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
oct_bar_updt= oct_night_group.plot.box(x= 'Date', y= 'Updated Alerts', color= 'green', title= 'Updated Alerts at Night')
oct_bar_updt
# Out:
# Analyst Name
# Aashvi Shukla     AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami     AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal      AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade     AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# #### November 2021

# %%
df_Nov= pd.read_excel('Daily_Analysis_Dec_2021.xlsx', sheet_name= 'November 2021', parse_dates= True)
df_Nov.head(10)
# Out:
#         Date   Analyst Name Reporting Shift Generated Alerts  Updated Alerts  \
# 0 2021-11-01  Jaya Warghade        Morning                12               8
# 1 2021-11-01  Aashvi Shukla       Afternoon               10              11
# 2 2021-11-01  Mirza Raichur           Night                2               9
# 3 2021-11-02  Jaya Warghade        Morning                10               8
# 4 2021-11-02  Aashvi Shukla       Afternoon                4               2
# 5 2021-11-02   Hitesh Yetal       Afternoon                7              19
# 6 2021-11-02  Ayaan Goswami           Night                3              12
# 7 2021-11-03  Jaya Warghade        Morning                10               6
# 8 2021-11-03   Hitesh Yetal       Afternoon               15              19
# 9 2021-11-03  Ayaan Goswami           Night                3              20
#
#    Feed Read New Sources              Activities Performed  Misc
# ...

# %%
df_Nov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  92 non-null     datetime64[ns]
#  1   Analyst Name          92 non-null     object
#  2   Reporting Shift       92 non-null     object
#  3   Generated Alerts      92 non-null     object
#  4   Updated Alerts        92 non-null     int64
#  5   Feed Read             92 non-null     int64
#  6   New Sources           92 non-null     object
#  7   Activities Performed  92 non-null     object
#  8   Misc                  91 non-null     object
# dtypes: datetime64[ns](1), int64(2), object(6)
# memory usage: 6.6+ KB

# %%
df_Nov['Generated Alerts'].replace('-',0, inplace= True)

# %%
clear_nov= df_Nov.drop(columns=['New Sources', 'Activities Performed', 'Misc'])
clear_nov.head(3)
# Out:
#         Date   Analyst Name Reporting Shift  Generated Alerts  Updated Alerts  \
# 0 2021-11-01  Jaya Warghade        Morning                 12               8
# 1 2021-11-01  Aashvi Shukla       Afternoon                10              11
# 2 2021-11-01  Mirza Raichur           Night                 2               9
#
#    Feed Read
# 0       7154
# 1       7654
# 2       7532

# %% [markdown]
# ##### Analysising who Generated and Updated more Alerts on November

# %%
nov_group= clear_nov.groupby('Analyst Name')
nov_group

# %%
nov_gen= nov_group.plot.bar(x='Date', y='Generated Alerts', color= 'green')
nov_gen
# Out:
# Analyst Name
# Aashvi Shukla    AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami    AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal     AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade    AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
nov_updt= nov_group.plot.bar(x= 'Date', y= 'Updated Alerts', color= 'pink')
nov_updt
# Out:
# Analyst Name
# Aashvi Shukla    AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami    AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal     AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade    AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# ##### Who did the most night shift in November

# %%
Nov_night= clear_nov['Reporting Shift']== 'Night'
Nov_night_shift= clear_nov[Nov_night]
Nov_night_shift.head()
# Out:
#          Date   Analyst Name Reporting Shift  Generated Alerts  \
# 2  2021-11-01  Mirza Raichur           Night                 2
# 6  2021-11-02  Ayaan Goswami           Night                 3
# 9  2021-11-03  Ayaan Goswami           Night                 3
# 12 2021-11-04  Ayaan Goswami           Night                 5
# 15 2021-11-05  Ayaan Goswami           Night                 2
#
#     Updated Alerts  Feed Read
# 2                9       7532
# 6               12       6124
# 9               20       6598
# 12              14       7023
# 15              12       6823

# %%
Nov_night_shift.value_counts('Analyst Name')
# Out:
# Analyst Name
# Aashvi Shukla    9
# Jaya Warghade    8
# Ayaan Goswami    5
# Hitesh Yetal     4
# Mirza Raichur    3
# dtype: int64

# %%
nov_night_group= Nov_night_shift.groupby("Analyst Name")
nov_night_group

# %%
nov_bar_gen= nov_night_group.plot.box(x= 'Date', y= 'Generated Alerts', color= 'purple', title= 'Generated Alerts at Night')
nov_bar_gen
# Out:
# Analyst Name
# Aashvi Shukla    AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami    AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal     AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade    AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
nov_bar_updt= nov_night_group.plot.box(x= 'Date', y= 'Updated Alerts', color= 'grey', title= 'Updated Alerts at Night')
nov_bar_updt
# Out:
# Analyst Name
# Aashvi Shukla    AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami    AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal     AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade    AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# #### December 2021

# %%
df_Dec= pd.read_excel('Daily_Analysis_Dec_2021.xlsx', sheet_name= 'December 2021', parse_dates= True)
df_Dec.head(43)
# Out:
#                    Date    Analyst Name Reporting Shift Generated Alerts  \
# 0                 44208   Ayaan Goswami        Morning                10
# 1                 44208  Aashvi Shukla        Afternoon               12
# 2                 44208   Jaya Warghade          Night                 2
# 3                 44239   Ayaan Goswami        Morning                12
# 4                 44239    Hitesh Yetal       Afternoon                9
# 5                 44239   Mirza Raichur          Night                 -
# 6                 44267   Ayaan Goswami        Morning                12
# 7                 44267    Hitesh Yetal       Afternoon               11
# 8                 44267   Mirza Raichur          Night                 1
# 9                 44298   Jaya Warghade        Morning                 5
# 10                44298    Hitesh Yetal       Afternoon                8
# 11                44298  Aashvi Shukla           Night                 4
# ...

# %%
Dec_df= df_Dec.drop(labels=range(0, 40), axis=0)
Dec_df.head(10)
# Out:
#                    Date    Analyst Name Reporting Shift Generated Alerts  \
# 40  2021-12-13 00:00:00  Aashvi Shukla         Morning                10
# 41  2021-12-13 00:00:00   Mirza Raichur       Afternoon                9
# 42  2021-12-13 00:00:00   Jaya Warghade       Afternoon                3
# 43  2021-12-13 00:00:00    Hitesh Yetal          Night                 4
# 44  2021-12-13 00:00:00   Ayaan Goswami          Night                 1
# 45  2021-12-14 00:00:00  Aashvi Shukla         Morning                 9
# 46  2021-12-14 00:00:00   Mirza Raichur       Afternoon                6
# 47  2021-12-14 00:00:00   Jaya Warghade       Afternoon                4
# 48  2021-12-14 00:00:00   Ayaan Goswami          Night                 2
# 49  2021-12-15 00:00:00   Jaya Warghade       Afternoon                4
#
#     Updated Alerts  Feed Read New Sources              Activities Performed  \
# 40               8       7654           -  Search updates for old incidents
# ...

# %%
Dec_df['Date']= pd.to_datetime(Dec_df['Date'])

# %%
Dec_df.head(10)
# Out:
#          Date    Analyst Name Reporting Shift Generated Alerts  \
# 40 2021-12-13  Aashvi Shukla         Morning                10
# 41 2021-12-13   Mirza Raichur       Afternoon                9
# 42 2021-12-13   Jaya Warghade       Afternoon                3
# 43 2021-12-13    Hitesh Yetal          Night                 4
# 44 2021-12-13   Ayaan Goswami          Night                 1
# 45 2021-12-14  Aashvi Shukla         Morning                 9
# 46 2021-12-14   Mirza Raichur       Afternoon                6
# 47 2021-12-14   Jaya Warghade       Afternoon                4
# 48 2021-12-14   Ayaan Goswami          Night                 2
# 49 2021-12-15   Jaya Warghade       Afternoon                4
#
#     Updated Alerts  Feed Read New Sources              Activities Performed  \
# 40               8       7654           -  Search updates for old incidents
# 41               4       7985           -  Search updates for old incidents
# ...

# %%
Dec_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 62 entries, 40 to 101
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  62 non-null     datetime64[ns]
#  1   Analyst Name          62 non-null     object
#  2   Reporting Shift       62 non-null     object
#  3   Generated Alerts      62 non-null     object
#  4   Updated Alerts        62 non-null     int64
#  5   Feed Read             62 non-null     int64
#  6   New Sources           61 non-null     object
#  7   Activities Performed  62 non-null     object
#  8   Misc                  61 non-null     object
# dtypes: datetime64[ns](1), int64(2), object(6)
# memory usage: 4.8+ KB

# %%
Dec_df['Generated Alerts']= Dec_df['Generated Alerts'].astype(int)

# %%
Dec_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 62 entries, 40 to 101
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  62 non-null     datetime64[ns]
#  1   Analyst Name          62 non-null     object
#  2   Reporting Shift       62 non-null     object
#  3   Generated Alerts      62 non-null     int32
#  4   Updated Alerts        62 non-null     int64
#  5   Feed Read             62 non-null     int64
#  6   New Sources           61 non-null     object
#  7   Activities Performed  62 non-null     object
#  8   Misc                  61 non-null     object
# dtypes: datetime64[ns](1), int32(1), int64(2), object(5)
# memory usage: 4.6+ KB

# %% [markdown]
# ##### Analysising who Generated and Updated more Alerts on December

# %%
dec_group= Dec_df.groupby('Analyst Name')
dec_group

# %%
dec_gen= dec_group.plot.bar(x='Date', y='Generated Alerts', color='yellow')

# %%
dec_updt= dec_group.plot.bar(x= 'Date', y= 'Updated Alerts', color= 'grey')

# %% [markdown]
# ##### Who did the most night shift in December

# %%
Dec_night= Dec_df['Reporting Shift']== 'Night '
Dec_night_shift=Dec_df[Dec_night]
Dec_night_shift.head()
# Out:
#          Date   Analyst Name Reporting Shift  Generated Alerts  \
# 43 2021-12-13   Hitesh Yetal          Night                  4
# 44 2021-12-13  Ayaan Goswami          Night                  1
# 48 2021-12-14  Ayaan Goswami          Night                  2
# 50 2021-12-15  Ayaan Goswami          Night                  2
# 53 2021-12-16  Ayaan Goswami          Night                  3
#
#     Updated Alerts  Feed Read New Sources              Activities Performed  \
# 43               4       5143           -  Search updates for old incidents
# 44               8       4125           -  Search updates for old incidents
# 48               9       7659           -  Search updates for old incidents
# 50              12       7569           -  Search updates for old incidents
# 53               8       6598           -  Search updates for old incidents
#
#     Misc
# 43  Blog
# 44     -
# 48  Blog
# 50     -
# 53     -

# %%
Dec_night_shift.value_counts('Analyst Name')
# Out:
# Analyst Name
# Aashvi Shukla     5
# Ayaan Goswami     5
# Mirza Raichur     5
# Jaya Warghade     4
# Hitesh Yetal      3
# dtype: int64

# %%
Dec_night_group= Dec_night_shift.groupby("Analyst Name")
Dec_night_group

# %%
dec_bar_gen= Dec_night_group.plot.box(x='Date', y='Generated Alerts', color='orange', title='Generated Alerts at Night')
dec_bar_gen
# Out:
# Analyst Name
# Aashvi Shukla     AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami     AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal      AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade     AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
dec_bar_upd= Dec_night_group.plot.box(x='Date', y='Updated Alerts', color='orange', title='Updated Alerts at Night')
dec_bar_upd
# Out:
# Analyst Name
# Aashvi Shukla     AxesSubplot(0.125,0.125;0.775x0.755)
# Ayaan Goswami     AxesSubplot(0.125,0.125;0.775x0.755)
# Hitesh Yetal      AxesSubplot(0.125,0.125;0.775x0.755)
# Jaya Warghade     AxesSubplot(0.125,0.125;0.775x0.755)
# Mirza Raichur     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# # Who reported and updated most alerts in the whole year

# %%
year_count= pd.concat([jan_clear,feb_clear,march_clear,clear_april,may_clear,clear_june,clean_july,clear_aug,clear_sep,clear_oct,clear_nov,Dec_df], axis=0, ignore_index=True)
year_count
# Out:
#            Date   Analyst Name Reporting Shift  Generated Alerts  \
# 0    2021-01-01  Jaya Warghade         Morning                 4
# 1    2021-01-01  Ayaan Goswami       Afternoon                10
# 2    2021-01-01  Mirza Raichur           Night                 1
# 3    2021-01-02  Jaya Warghade         Morning                 8
# 4    2021-01-02   Hitesh Yetal       Afternoon                17
# ...         ...            ...             ...               ...
# 1179 2021-12-30  Ayaan Goswami       Afternoon                12
# 1180 2021-12-30   Hitesh Yetal          Night                  4
# 1181 2021-12-31  Mirza Raichur        Morning                  8
# 1182 2021-12-31  Ayaan Goswami       Afternoon                 7
# 1183 2021-12-31   Hitesh Yetal          Night                  6
#
#       Updated Alerts Misc Feed Read New Sources  \
# 0                 11    -       NaN         NaN
# 1                 11    -       NaN         NaN
# ...

# %%
year_count.describe()
# Out:
#        Generated Alerts  Updated Alerts
# count       1184.000000     1184.000000
# mean           5.991554       11.098818
# std            4.171302        5.061201
# min            0.000000        1.000000
# 25%            3.000000        8.000000
# 50%            5.000000       10.000000
# 75%            9.000000       14.000000
# max           22.000000       30.000000

# %% [markdown]
# #### Saving the DataFram to CSV

# %%
# write_df= year_count.to_csv('3_year_count.csv')
# write_df
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30492/2125293165.py in <module>
# ----> 1 write_df= year_count.to_csv('3_year_count.csv')
#       2 write_df
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3464         )
#    3465
# -> 3466         return DataFrameRenderer(formatter).to_csv(
#    3467             path_or_buf,
#    3468             line_terminator=line_terminator,
#
# ...

# %%
year_count['Month']= year_count['Date'].dt.month_name()
year_count

# %%
year_count.info()

# %%
year_group= year_count.groupby('Analyst Name')
year_group

# %% [markdown]
# #####  Hitesh Yetal

# %%
Hitesh_graph= year_group.get_group("Hitesh Yetal")
Hitesh_graph

# %%
Hitesh_graph_piv= Hitesh_graph.pivot_table(index= 'Month', columns= 'Analyst Name', values=['Generated Alerts', 'Updated Alerts'], aggfunc='sum', sort=False)
Hitesh_graph_piv

# %%
Hitesh_graph['Generated Alerts'].sum()

# %%
Hitesh_graph['Updated Alerts'].sum()

# %%
Hitesh_graph_piv.plot.bar(figsize=(20,10))

# %% [markdown]
# #### Mirza Raichur

# %%
Mirza_graph= year_group.get_group("Mirza Raichur")
Mirza_graph

# %%
Mirza_graph_piv= Mirza_graph.pivot_table(index= 'Month', columns='Analyst Name', values=['Generated Alerts', 'Updated Alerts'], aggfunc='sum', sort= False)
Mirza_graph_piv

# %%
Mirza_graph['Generated Alerts'].sum()

# %%
Mirza_graph['Updated Alerts'].sum()

# %%
Mirza_graph_bar= Mirza_graph_piv.plot.bar(figsize= (20,10))
Mirza_graph_bar

# %% [markdown]
# #### Ayaan Goswami

# %%
Ayaan_graph= year_group.get_group("Ayaan Goswami")
Ayaan_graph

# %%
Ayaan_graph_piv= Ayaan_graph.pivot_table(index= 'Month', columns='Analyst Name', values= ['Generated Alerts', 'Updated Alerts'], aggfunc= 'sum',sort= False)
Ayaan_graph_piv

# %%
Ayaan_graph_piv['Generated Alerts'].sum()

# %%
Ayaan_graph_piv['Updated Alerts'].sum()

# %%
Ayaan_graph_bar= Ayaan_graph_piv.plot.bar(figsize=(20,10))
Ayaan_graph_bar

# %% [markdown]
# #### Aashvi Shukla

# %%
Aashvi_graph= year_group.get_group("Aashvi Shukla")
Aashvi_graph

# %%
Aashvi_graph_piv= Aashvi_graph.pivot_table(index='Month', columns='Analyst Name', values=['Generated Alerts', 'Updated Alerts'], aggfunc='sum', sort=False)
Aashvi_graph_piv

# %%
Aashvi_graph_piv['Generated Alerts'].sum()

# %%
Aashvi_graph_piv['Updated Alerts'].sum()

# %%
Aashvi_graph_bar= Aashvi_graph_piv.plot.bar(figsize=(20,10))
Aashvi_graph_bar

# %% [markdown]
# #### Jaya Warghade

# %%
Jaya_graph= year_group.get_group("Jaya Warghade")
Jaya_graph

# %%
Jaya_graph_piv=Jaya_graph.pivot_table(index='Month', columns='Analyst Name', values=['Generated Alerts', "Updated Alerts"], aggfunc='sum', sort=False)
Jaya_graph_piv

# %%
Jaya_graph_piv['Generated Alerts'].sum()

# %%
Jaya_graph_piv['Updated Alerts'].sum()

# %%
Jaya_graph_bar= Jaya_graph_piv.plot.bar(figsize= (20,10))
Jaya_graph_bar
